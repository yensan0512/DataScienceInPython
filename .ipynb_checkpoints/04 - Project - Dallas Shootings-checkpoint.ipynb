# %% [markdown]
# # Project - Dallas Shootings

# %% [markdown]
# ![Data Science Workflow](img/ds-workflow.png)

# %% [markdown]
# ## Goal of Project
# - A newspaper want a visualization of the shootings in Dallas with focus on subjects
# - We will read data from from database and join into broader datasets
# - We will explore ideas to visualize it and create a map with the shootings

# %% [markdown]
# ## Step 1: Acquire
# - Explore problem
# - Identify data
# - Import data

# %% [markdown]
# ### Step 1.a: Import libraries
# - Execute the cell below (SHIFT + ENTER)

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# ### Step 1.b: Connect to SQLite database
# - Use `sqlite3.connect(<filename>)` to connect to the database `files/dallas-ois.sqlite`

# %%
conn = sqlite3.connect('files/dallas-ois.sqlite')

# %% [markdown]
# ### Step 1. c: Read data into DataFrames
# - The database consists of 3 tables: `incident`, `officers`, `subjects`
# - Read the data from each table into a DataFrame.
# - HINT: Use `pandas` `read_sql(sql_stmt, conn)`, which takes the SQL statement (`sql_stmt`) and the data base connection `conn` from previous step.
# - HINT: The structure of the SQL statement is as follows.
# ```SQL
# SELECT * FROM table
# ```

# %%
incident = pd.read_sql('SELECT * FROM incidents',conn)
officers = pd.read_sql('SELECT * FROM officers',conn)
subjects = pd.read_sql('SELECT * FROM subjects',conn)

# %% [markdown]
# ### Step 1.d: Explore the length of the DataFrames
# - What is the length of the DataFrames
#     - HINT: Apply `len(...)` on the DataFrames
# - We want to explore data based on officers and data based on subjects, both with incident data.
# - Notice: It is difficult to create one dataset for both problems
# - Explore data further to understand why

# %%
len(incident),len(officers),len(subjects)
# Out:
# (219, 370, 223)

# %%
incident.head()
# Out:
#   case_number        date                  location subject_statuses  \
# 0      44523A  2013-02-23     3000 Chihuahua Street          Injured
# 1     121982X  2010-05-03  1300 N. Munger Boulevard          Injured
# 2     605484T  2007-08-12   200 S. Stemmons Freeway            Other
# 3     384832T  2007-05-26           7900 S. Loop 12   Shoot and Miss
# 4     244659R  2006-04-03        6512 South Loop 12          Injured
#
#   subject_weapon                                           subjects  \
# 0        Handgun                                   Curry, James L/M
# 1        Handgun                                Chavez, Gabriel L/M
# 2        Shotgun                                  Salinas, Nick L/M
# 3        Unarmed  Smith, James B/M; Dews, Antonio B/M; Spearman,...
# 4          Hands                                 Watkins, Caleb B/M
#
#    subject_count                                   officers  officer_count  \
# 0              1  Patino, Michael L/M; Fillingim, Brian W/M              2
# 1              1                       Padilla, Gilbert L/M              1
# 2              1                          Poston, Jerry W/M              1
# 3              3                         Mondy, Michael B/M              1
# 4              1                     Armstrong, Michael W/M              1
#
#   grand_jury_disposition attorney_general_forms_url  \
# 0                No Bill                       None
# 1                No Bill                       None
# 2            See Summary                       None
# 3                   None                       None
# 4                No Bill                       None
#
#                                          summary_url  \
# 0  http://dallaspolice.net/reports/OIS/narrative/...
# 1  http://dallaspolice.net/reports/OIS/narrative/...
# 2  http://dallaspolice.net/reports/OIS/narrative/...
# 3  http://dallaspolice.net/reports/OIS/narrative/...
# 4  http://dallaspolice.net/reports/OIS/narrative/...
#
#                                         summary_text  latitude  longitude
# 0  On Saturday, February 23, 2013, at approximate...       NaN        NaN
# 1  On Monday, May 3, 2010, at approximately 8:06 ...       NaN        NaN
# 2  On Sunday, August 12, 2007, at approximately 2...       NaN        NaN
# 3  On Saturday, May 26, 2007, at approximately 1:...       NaN        NaN
# 4  On Monday, April 3, 2006, at approximately 11:...       NaN        NaN

# %% [markdown]
# ### Step 1.e: Read data into dataset
# - Create first dataset `subject_incidents` as officers joined with incidents.
#     - What does this dataset give us?
#     - HINT:
#     ```SQL
#     SELECT * FROM table_1 JOIN table_2 ON table_1.column_name_1=table_2.column_name_2
#     ```
#     - HINT: You can join on columns `case_number`
# - Is all data represented?

# %%
subject_incident = pd.read_sql('SELECT * FROM incidents JOIN subjects ON incidents.case_number=subjects.case_number',conn)

# %%
len(subject_incident)
# Out:
# 223

# %%
subject_incident.head()
# Out:
#    case_number        date                  location subject_statuses  \
# 0       44523A  2013-02-23     3000 Chihuahua Street          Injured
# 1      121982X  2010-05-03  1300 N. Munger Boulevard          Injured
# 2      605484T  2007-08-12   200 S. Stemmons Freeway            Other
# 3      384832T  2007-05-26           7900 S. Loop 12   Shoot and Miss
# 4      384832T  2007-05-26           7900 S. Loop 12   Shoot and Miss
#
#   subject_weapon                                           subjects  \
# 0        Handgun                                   Curry, James L/M
# 1        Handgun                                Chavez, Gabriel L/M
# 2        Shotgun                                  Salinas, Nick L/M
# 3        Unarmed  Smith, James B/M; Dews, Antonio B/M; Spearman,...
# 4        Unarmed  Smith, James B/M; Dews, Antonio B/M; Spearman,...
#
#    subject_count                                   officers  officer_count  \
# 0              1  Patino, Michael L/M; Fillingim, Brian W/M              2
# 1              1                       Padilla, Gilbert L/M              1
# 2              1                          Poston, Jerry W/M              1
# 3              3                         Mondy, Michael B/M              1
# 4              3                         Mondy, Michael B/M              1
#
#   grand_jury_disposition  ...  \
# 0                No Bill  ...
# 1                No Bill  ...
# 2            See Summary  ...
# 3                   None  ...
# 4                   None  ...
#
#                                          summary_url  \
# 0  http://dallaspolice.net/reports/OIS/narrative/...
# 1  http://dallaspolice.net/reports/OIS/narrative/...
# 2  http://dallaspolice.net/reports/OIS/narrative/...
# 3  http://dallaspolice.net/reports/OIS/narrative/...
# 4  http://dallaspolice.net/reports/OIS/narrative/...
#
#                                         summary_text latitude  longitude  \
# 0  On Saturday, February 23, 2013, at approximate...      NaN        NaN
# 1  On Monday, May 3, 2010, at approximately 8:06 ...      NaN        NaN
# 2  On Sunday, August 12, 2007, at approximately 2...      NaN        NaN
# 3  On Saturday, May 26, 2007, at approximately 1:...      NaN        NaN
# 4  On Saturday, May 26, 2007, at approximately 1:...      NaN        NaN
#
#    case_number race gender last_name first_name        full_name
# 0       44523A    L      M     Curry      James     Curry, James
# 1      121982X    L      M    Chavez    Gabriel  Chavez, Gabriel
# 2      605484T    L      M   Salinas       Nick    Salinas, Nick
# 3      384832T    B      M     Smith      James     Smith, James
# 4      384832T    B      M      Dews    Antonio    Dews, Antonio
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Step 2: Prepare
# - Explore data
# - Visualize ideas
# - Cleaning data

# %% [markdown]
# ### Step 2.a: Check the data types
# - A step to get to understand the data better is to explore the data types
# - Get the data types by `.dtypes`

# %%
subject_incident.dtypes
# Out:
# case_number                    object
# date                           object
# location                       object
# subject_statuses               object
# subject_weapon                 object
# subjects                       object
# subject_count                   int64
# officers                       object
# officer_count                   int64
# grand_jury_disposition         object
# attorney_general_forms_url     object
# summary_url                    object
# summary_text                   object
# latitude                      float64
# longitude                     float64
# case_number                    object
# race                           object
# gender                         object
# last_name                      object
# first_name                     object
# full_name                      object
# dtype: object

# %% [markdown]
# ### Step 2.b: Check for null (missing) values
# - Data often is missing entries - there can be many reasons for this
# - We need to deal with that (will do later in course)
# - Use ```.isna().sum()```

# %%
subject_incident.isna().sum()
# Out:
# case_number                     0
# date                            0
# location                        0
# subject_statuses                0
# subject_weapon                  0
# subjects                        0
# subject_count                   0
# officers                        0
# officer_count                   0
# grand_jury_disposition         88
# attorney_general_forms_url    221
# summary_url                     3
# summary_text                    3
# latitude                        9
# longitude                       9
# case_number                     0
# race                            0
# gender                          0
# last_name                       0
# first_name                     18
# full_name                       0
# dtype: int64

# %% [markdown]
# ### Step 2.c: Explore subject_statuses column
# - As part of finding useful features let's explore `subject_statuses`
# - We know that `subject_statuses` is categorical.
# - Therefore we can use `groupby(...)` and `count()`

# %%
subject_incident.groupby('subject_statuses').count()
# Out:
#                       case_number  date  location  subject_weapon  subjects  \
# subject_statuses
# 1 Deceased 1 Injured            2     2         2               2         2
# 2 Injured                       1     1         1               1         1
# Deceased                       69    69        69              69        69
# Deceased Injured                2     2         2               2         2
# Injured                        60    60        60              60        60
# Other                           2     2         2               2         2
# Shoot and Miss                 87    87        87              87        87
#
#                       subject_count  officers  officer_count  \
# subject_statuses
# 1 Deceased 1 Injured              2         2              2
# 2 Injured                         1         1              1
# Deceased                         69        69             69
# Deceased Injured                  2         2              2
# Injured                          60        60             60
# Other                             2         2              2
# Shoot and Miss                   87        87             87
#
#                       grand_jury_disposition  attorney_general_forms_url  \
# subject_statuses
# 1 Deceased 1 Injured                       2                           0
# 2 Injured                                  1                           0
# Deceased                                  67                           1
# Deceased Injured                           2                           0
# Injured                                   58                           1
# Other                                      1                           0
# Shoot and Miss                             4                           0
#
#                       summary_url  summary_text  latitude  longitude  \
# subject_statuses
# 1 Deceased 1 Injured            2             2         2          2
# 2 Injured                       1             1         1          1
# Deceased                       67            67        68         68
# Deceased Injured                2             2         2          2
# Injured                        60            60        57         57
# Other                           2             2         1          1
# Shoot and Miss                 86            86        83         83
#
#                       case_number  race  gender  last_name  first_name  \
# subject_statuses
# 1 Deceased 1 Injured            2     2       2          2           2
# 2 Injured                       1     1       1          1           1
# Deceased                       69    69      69         69          67
# Deceased Injured                2     2       2          2           2
# Injured                        60    60      60         60          60
# Other                           2     2       2          2           2
# Shoot and Miss                 87    87      87         87          71
#
#                       full_name
# subject_statuses
# 1 Deceased 1 Injured          2
# 2 Injured                     1
# Deceased                     69
# Deceased Injured              2
# Injured                      60
# Other                         2
# Shoot and Miss               87

# %% [markdown]
# ### Step 2.d: Explore race column
# - Repeat of previous step on column `race`

# %%
subject_incident.groupby('race').count()
# Out:
#       case_number  date  location  subject_statuses  subject_weapon  subjects  \
# race
# A               2     2         2                 2               2         2
# B             111   111       111               111             111       111
# L              72    72        72                72              72        72
# W              38    38        38                38              38        38
#
#       subject_count  officers  officer_count  grand_jury_disposition  \
# race
# A                 2         2              2                       0
# B               111       111            111                      67
# L                72        72             72                      37
# W                38        38             38                      31
#
#       attorney_general_forms_url  summary_url  summary_text  latitude  \
# race
# A                              0            2             2         2
# B                              0          109           109       106
# L                              2           71            71        68
# W                              0           38            38        38
#
#       longitude  case_number  gender  last_name  first_name  full_name
# race
# A             2            2       2          2           2          2
# B           106          111     111        111         104        111
# L            68           72      72         72          61         72
# W            38           38      38         38          38         38

# %% [markdown]
# ### Step 2.e: Explore more columns
# - Feel free to explore more columns (also called features)

# %%
subject_incident.groupby('gender').count()
# Out:
#         case_number  date  location  subject_statuses  subject_weapon  \
# gender
# F                 8     8         8                 8               8
# M               215   215       215               215             215
#
#         subjects  subject_count  officers  officer_count  \
# gender
# F              8              8         8              8
# M            215            215       215            215
#
#         grand_jury_disposition  attorney_general_forms_url  summary_url  \
# gender
# F                            5                           0            8
# M                          130                           2          212
#
#         summary_text  latitude  longitude  case_number  race  last_name  \
# gender
# F                  8         8          8            8     8          8
# M                212       206        206          215   215        215
#
#         first_name  full_name
# gender
# F                7          8
# M              198        215

# %% [markdown]
# ### Step 2.f: Visualize ideas
# - We want to make a visual plot of the shooting incident
# - Let's explore if we can make a plot based on longitude and latitude.
#     - HINT: use `plot.scatter(x='longitude', y='latitude')`
# - Then the analysis phase will focus on how to make useful insights with the feature selections.

# %%
subject_incident.plot.scatter(x='longitude',y='latitude')
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# ## Step 3: Analyze
# - Feature selection
# - Model selection
# - Analyze data

# %% [markdown]
# ### Step 3.a: Feature selection
# - Here we will continue with the features selected feel free to explore other features.
# - Create a `dataset` with the features: `race`, `subject_statuses`, `latitude`, `longitude`
#     - HINT: Select the features of the DataFrame `subject_incidents` by filtering with a list of the columns.
# - To make further processing easier apply `dropna()` to remove missing data.

# %%
dataset = subject_incident[['race','longitude','subject_statuses','latitude']].dropna()

# %%
len(dataset)
# Out:
# 214

# %% [markdown]
# ### Step 3.b: How to visualize features
# - We want to visualize the two features: `race` and `subject_statuses`
# - A way to visualize data is by color and size.
# - Idea:
#     - Map the race features to colors
#     - Map the subject_statuses to a size

# %% [markdown]
# ### Step 3.b.1: Convert column
# - The `race` column has the following categories: B, W, A, L
# - We can map that to color values ([docs](https://matplotlib.org/stable/gallery/color/named_colors.html))
# - A simple way to map columns is by using `apply` on a lambda-function.
#     - Create a dict with the mapping:
#     ```Python
# mapping = {'B': 'blue', 'W': 'yellow', 'A': 'red', 'L': 'cyan'}
# ```
#     - Do the mapping with `apply`and `lambda` as follows
#     ```Python
# dataset['race'] = dataset['race'].apply(lambda x: mapping[x])
# ```

# %%
mapping = {'B': 'blue', 'W': 'yellow', 'A': 'red', 'L': 'cyan'}
dataset['race'] = dataset['race'].apply(lambda x: mapping[x])
dataset.head()
# Out:
#       race  longitude subject_statuses  latitude
# 9     cyan -96.908674         Deceased  32.68642
# 10    blue -96.898998         Deceased  32.86400
# 11  yellow -96.826787   Shoot and Miss  32.81482
# 12    blue -96.767489          Injured  32.77540
# 13    blue -96.828470   Shoot and Miss  32.74417

# %% [markdown]
# ### Step 3.b.2: Convert column
# - The `subject_statuses` has the following categories: `'1 Deceased 1 Injured', '2 Injured', 'Deceased', 'Deceased Injured', 'Injured', 'Other', 'Shoot and Miss'`
# - The main categories are: `'Deceased', 'Injured', 'Shoot and Miss'`
# - A simple way is quite similar to last step.
#     - Create a mapping of the main categories:
#     ```Python
# mapping = {'Deceased': 1000, 'Injured': 500, 'Shoot and Miss': 250}
# ```
#     - Do the mapping with `apply`and `lambda` as follows
#     ```Python
# dataset['subject_statuses'] = dataset['subject_statuses'].apply(lambda x: mapping.get(x, 100))
# ```

# %%
mapping = {'Deceased': 1000, 'Injured': 500, 'Shoot and Miss': 250}
dataset['subject_statuses'] = dataset['subject_statuses'].apply(lambda x: mapping.get(x, 100))
dataset.head()
# Out:
#       race  longitude  subject_statuses  latitude
# 9     cyan -96.908674              1000  32.68642
# 10    blue -96.898998              1000  32.86400
# 11  yellow -96.826787               250  32.81482
# 12    blue -96.767489               500  32.77540
# 13    blue -96.828470               250  32.74417

# %% [markdown]
# ### Step 3.c: Visualize the data
# - Now we can visualize the data
# - This can be done with a scatter plot
# ```Python
# dataset.plot.scatter(x='longitude', y='latitude', s='subject_statuses', c='race', alpha=.5)
# ```
# - Where `s=` is the size feature and `c=` is the color feature, `figsize=` sets the size of the figure, `alpha=` sets the transparency of the dots.

# %%
dataset.plot.scatter(x='longitude', y='latitude', s='subject_statuses', c='race', alpha=.5)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# ## Step 4: Report
# - Present findings
# - Visualize results
# - Credibility counts

# %% [markdown]
# ### Step 4.a: Present a chart
# - The goal here is to present your message
# - Visualize one chart
# - Add a headline (title) to give the audience a message

# %%
dataset.plot.scatter(x='longitude', y='latitude', s='subject_statuses', c='race', alpha=.25,title='Dallas shootings')
# Out:
# <AxesSubplot:title={'center':'Dallas shootings'}, xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# ### Step 4.b (Optional): Further improvements
# - Ideas to improve the visualization
# - Add description (legends) with color and size description.
# - Visualize it on a map
#     - You could use [folium](https://python-visualization.github.io/folium/)
#     - Explore [quick guide](https://python-visualization.github.io/folium/quickstart.html)

# %%
#! pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.14.0-py2.py3-none-any.whl (102 kB)
#      -------------------------------------- 102.3/102.3 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: jinja2>=2.9 in c:\users\yensanwoo\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: numpy in c:\users\yensanwoo\anaconda3\lib\site-packages (from folium) (1.21.5)
# Collecting branca>=0.6.0
#   Downloading branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in c:\users\yensanwoo\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\yensanwoo\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yensanwoo\anaconda3\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yensanwoo\anaconda3\lib\site-packages (from requests->folium) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yensanwoo\anaconda3\lib\site-packages (from requests->folium) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\yensanwoo\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Installing collected packages: branca, folium
# Successfully installed branca-0.6.0 folium-0.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
m = folium.Map(location=[32.8, -96.8])

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1168992db228a5a77fc66b7f9edd6b5a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1168992db228a5a77fc66b7f9edd6b5a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1168992db228a5a77fc66b7f9edd6b5a = L.map(
#                 &quot;map_1168992db228a5a77fc66b7f9edd6b5a&quot;,
#                 {
#                     center: [32.8, -96.8],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8bc642a2cdbc26b0a8ec4b77d1b1f66 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1168992db228a5a77fc66b7f9edd6b5a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for _, row in dataset.iterrows():
    folium.CircleMarker(
    location=[row['latitude'], row['longitude']],
    radius=row['subject_statuses']//100,
    color=row['race'],
    fill=True,
    fill_color=row['race']
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1168992db228a5a77fc66b7f9edd6b5a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1168992db228a5a77fc66b7f9edd6b5a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1168992db228a5a77fc66b7f9edd6b5a = L.map(
#                 &quot;map_1168992db228a5a77fc66b7f9edd6b5a&quot;,
#                 {
#                     center: [32.8, -96.8],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8bc642a2cdbc26b0a8ec4b77d1b1f66 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1168992db228a5a77fc66b7f9edd6b5a);
#
#
#             var circle_marker_7b8d8d7ea69adca8d77db31918a46ed2 = L.circleMarker(
#                 [32.68642, -96.908674],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cyan&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cyan&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1168992db228a5a77fc66b7f9edd6b5a);
#
#
#             var circle_marker_9d59a201e27a2854f01323579ec14730 = L.circleMarker(
#                 [32.864, -96.898998],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1168992db228a5a77fc66b7f9edd6b5a);
#
#
#             var circle_marker_7d2db47b2673b151cc457eadd7a5dfbe = L.circleMarker(
#                 [32.81482, -96.826787],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1168992db228a5a77fc66b7f9edd6b5a);
#
#
#             var circle_marker_32a0aa66211aefe3835ed4558d7ab484 = L.circleMarker(
#                 [32.7754, -96.767489],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1168992db228a5a77fc66b7f9edd6b5a);
#
#
#             var circle_marker_cd26b93da3c412010baad3f488b7c24d = L.circleMarker(
#                 [32.74417, -96.82847],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1168992db228a5a77fc66b7f9edd6b5a);
#
#
#             var circle_marker_c6c161ab64f93562efec0f636a4b8882 = L.circleMarker(
#                 [32.945, -96.822619],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cyan&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cyan&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1168992db228a5a77fc66b7f9edd6b5a);
#
#
#             var circle_marker_62e0e4f8fd62e716e97cf4a8593648b0 = L.circleMarker(
#                 [33.0073, -96.8319

# %% [markdown]
# ## Step 5: Actions
# - Use insights
# - Measure impact
# - Main goal

# %% [markdown]
# ### Step 5.a (Optional): Are there any insights?
# - Any insights you want to highlight?
# - Any future measurements?
